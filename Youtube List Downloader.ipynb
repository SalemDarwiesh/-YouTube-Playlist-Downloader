# %%
import yt_dlp

def download_playlist(playlist_url, download_path):
    # Configure the download options
    ydl_opts = {
        'format': 'best',  # You can change the format to 'bestvideo' or 'bestaudio' as needed
        'outtmpl': f'{download_path}/%(title)s.%(ext)s',  # Save with video title
    }

    # Use yt_dlp to download the playlist
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([playlist_url])

if __name__ == "__main__":
    # Replace with the URL of the YouTube playlist you want to download
    playlist_url = ""

    # Replace with the directory where you want to save the videos
    download_path = ""  # Adjust the path as needed

    # Start downloading
    download_playlist(playlist_url, download_path)
# Out:
# 2025-01-23 15:41:29,860 - ERROR - Unexpected error converting القران الكريم - مشاري راشد الصفحة 1.mp4: [WinError 2] The system cannot find the file specified
# 2025-01-23 15:41:29,894 - ERROR - Unexpected error converting القران الكريم - مشاري راشد الصفحة 10.mp4: [WinError 2] The system cannot find the file specified
# 2025-01-23 15:41:29,931 - ERROR - Unexpected error converting القران الكريم - مشاري راشد الصفحة 100.mp4: [WinError 2] The system cannot find the file specified
# 2025-01-23 15:41:29,949 - ERROR - Unexpected error converting القران الكريم - مشاري راشد الصفحة 101.mp4: [WinError 2] The system cannot find the file specified
# 2025-01-23 15:41:29,967 - ERROR - Unexpected error converting القران الكريم - مشاري راشد الصفحة 102.mp4: [WinError 2] The system cannot find the file specified
# 2025-01-23 15:41:29,983 - ERROR - Unexpected error converting القران الكريم - مشاري راشد الصفحة 103.mp4: [WinError 2] The system cannot find the file specified
# ...
